# %% [markdown]
# # МАДМО
#
# <a href="https://mipt.ru/science/labs/laboratoriya-neyronnykh-sistem-i-glubokogo-obucheniya/"><img align="right" src="https://avatars1.githubusercontent.com/u/29918795?v=4&s=200" alt="DeepHackLab" style="position:relative;top:-40px;right:10px;height:100px;" /></a>
#
#
#
# ### Физтех-Школа Прикладной математики и информатики МФТИ
# ### Лаборатория нейронных сетей и глубокого обучения (DeepHackLab)
# Домашнее задание необходимо загрузить в общий репозиторий с именной папкой

# %% [markdown]
# ## Домашнее задание 1
# ### Основы Python и пакет NumPy
# ---

# %%
import numpy as np
import random
import scipy.stats as sps

# %% [markdown]
# ### Задача 1
# В первой задаче вам предлагается перемножить две квадратные матрицы двумя способами -- без использования пакета ***numpy*** и с ним.

# %%
# Для генерации матриц используем фукнцию random -- она используется для генерации случайных объектов 
# функция sample создает случайную выборку. В качестве аргумента ей передается кортеж (i,j), здесь i -- число строк,
# j -- число столбцов.
a = np.random.sample((100,100))
b = np.random.sample((100,100))
# выведите размерность (ранг) каждой матрицы с помощью функции ndim.

'''Надежда, не совсем понятно - как можно посчитать ранг с помощью функции, которая выводит кол-во измерений?
Т.е. для одномерного массива - 1, для матрицы - 2 и т.д. 
Или я что-то делаю не так?
'''
print(a[0,:].ndim)
print(a.ndim)
print(np.random.sample((5,5,5)).ndim)

# Используйте функцию shape, что она вывела?
#shape выводит размер матрицы - кол-во строк и столбцов.
# ========
# тут можно писать код 
a = np.matrix(a)
    
def find_rank(matrix):
    
    matrix_copy=matrix
    
    n_row=matrix.shape[0]
    n_col=matrix.shape[1]
 
#Ищем зависимые ряды
    for i in range(n_row):      
        for j in range(n_row):
            if np.all(matrix[i,:]==0): 
                matrix_copy=np.delete(matrix_copy, i, 0)
            
            if i!=j and np.all(matrix[i,:]!=0) and  np.all(matrix[j,:]!=0):
                
                prod=np.inner(
                    matrix[i,:],
                    matrix[j,:]
                )
                
                temp_i=np.linalg.norm(matrix[i,:])
                temp_j=np.linalg.norm(matrix[j,:])
                
                if np.abs(prod-temp_i*temp_j) ==0:
                    matrix_copy=np.delete(matrix_copy, i, 0)
                    matrix[i,:]=0 
                    
                    
 #Ищем зависимые колонки   
    for x in range(n_col):      
        for y in range(n_col):
            
            if np.all(matrix[:,x]==0): 
                matrix_copy=np.delete(matrix_copy, x, 1)
            
            if i!=j and np.all(matrix[:,x]!=0) and  np.all(matrix[:,y]!=0):
                
                prod=np.inner(
                    matrix[:,x],
                    matrix[:,y]
                )
                
                temp_i=np.linalg.norm(matrix[:,x])
                temp_j=np.linalg.norm(matrix[:,y])
                
                if np.abs(prod-temp_i*temp_j) ==0:
                    matrix_copy=np.delete(matrix_copy, x, 1)
                    matrix[:,x]=0                             
    
    return matrix_copy.shape[0]
  
print('Function returns rank of '+ str(find_rank(a)))
print('The real answer is '+str(np.linalg.matrix_rank(a)))

#########################################
print('размер матрицы а = '+str(a.shape))
print('размер матрицы b = '+str(b.shape))
# Out:
# 2
# 1
# 3
# Function returns rank of 100
# The real answer is 100
# размер матрицы а = (100, 100)
# размер матрицы b = (100, 100)

# %%
'''Эта функция умножает матрицы (вложенные листы) без преобразования с помошью Numpy'''
#For base python only
a=[[0,1,6],[2,3,2],[6,6,1],[7,8,3]]
b=[[4,5,8,1],[6,7,8,1],[1,2,3,4]]

def matrix_mult(x,y):

    col_x=len(x[0])
    col_y=len(y[0])
    row_x=len(x)
    row_y=len(y)


    if (col_x!=row_y):
        print('WARNING! Number of columns of matrix \'a\' must be equal to the number of rows of matrix \'b\'')
        return None


    res=[]
    for i in range(row_x):
        res_col=[]
        for j in range(col_y):
            val=[]
            for s in range(col_x):
                val.append(x[i][s]*y[s][j])

            res_col.append(sum(val))
        res.append(res_col)

    return res

print(matrix_mult(a,b))
# Out:
# [[12, 19, 26, 25], [28, 35, 46, 13], [61, 74, 99, 16], [79, 97, 129, 27]]

# %%
'''Эта функция, которая использует массивы Numpy, но не использует встроенное умножение матриц'''
a = np.random.sample((100,100))
b = np.random.sample((100,100))

def mult(x, y):
    # здесь напишите перемножение матриц без 
    # использования NumPy и выведите результат 
    x=np.matrix(x)
    y=np.matrix(y)
    
    row_x, col_x=x.shape
    row_y, col_y=y.shape

    if (col_x!=row_y):
        print('WARNING! Number of columns of matrix \'a\' must be equal to the number of rows of matrix \'b\'')
        return None


    res=[]
    for i in range(row_x):
        res_col=[]
        for j in range(col_y):
            val=[]
            for s in range(col_x):
                val.append(x[i,s]*y[s,j])

            res_col.append(sum(val))
        res.append(res_col)

    return res

r1=mult(a,b)

def np_mult(a, b):
    # здесь напишите перемножение матриц с
    # использованием NumPy и выведите результат
    a=np.matrix(a)
    b=np.matrix(b)
    return a*b


r2=np_mult(a,b)
r2=r2.tolist()

print(np.all(np.subtract(r1, r2))<0.0001)
# Out:
# True

# %%
# %%time
# засечем время работы функции без NumPy
mult(a,b)
# Out:
# Wall time: 1.83 s
# [[22.93511090450836,
#   23.676539083655431,
#   24.536652850508478,
#   23.023738216948356,
#   25.949746208171391,
#   23.242295916667022,
#   28.896656152716918,
#   27.560564306801343,
#   27.461787041191226,
#   27.249888926705893,
#   24.08076684519126,
#   23.742728522459984,
#   25.472457855854501,
#   21.897943851171178,
#   26.754831973850681,
#   27.832960365595941,
#   22.048921735644658,
#   27.49447412519195,
#   26.68162891859258,
#   24.891957739910087,
#   22.59233277432747,
#   24.665058327824294,
#   21.287004012668095,
#   27.780681840796618,
#   23.706577371670416,
#   24.087347624278717,
#   25.068107762032241,
#   25.508000839151165,
#   25.46135590926319,
#   25.45921547440738,
#   25.774527521814882,
#   22.08475994318151,
#   25.065642375204543,
#   24.367816375496776,
#   25.473650395020812,
#   24.499583194362703,
#   23.513596187589382,
#   28.426657804185947,
#   24.503883288728368,
#   28.294241846788641,
#   24.15244211898646,
# ...

# %%
# %%time
# засечем время работы функции с NumPy
np_mult(a,b)
# Out:
# Wall time: 2 ms
# matrix([[ 22.9351109 ,  23.67653908,  24.53665285, ...,  23.07016874,
#           22.07568211,  23.14323321],
#         [ 22.00966449,  22.45009924,  23.69653309, ...,  25.1560471 ,
#           23.75422085,  21.73188422],
#         [ 22.34383111,  24.49814377,  25.42187242, ...,  24.41457906,
#           23.94656449,  22.11392872],
#         ...,
#         [ 22.52032872,  23.03653672,  24.11593795, ...,  25.82957835,
#           24.68750594,  21.42995991],
#         [ 22.75613157,  24.28516617,  24.70614548, ...,  25.3886314 ,
#           23.41160675,  22.8306496 ],
#         [ 23.24376471,  23.97139075,  25.685946  , ...,  23.96566332,
#           22.93627898,  23.3311827 ]])

# %% [markdown]
# ### Задача 2
# Напишите функцию, которая по данной последовательности $\{A_i\}_{i=1}^n$ строит последовательность $S_n$, где $S_k = \frac{A_1 + ... + A_k}{k}$.
# Аналогично -- с помощью библиотеки **NumPy** и без нее. Сравните скорость, объясните результат.

# %%
# функция, решающая задачу с помощью NumPy
def sec_av(A):
    return np.mean(A)

sec_av(a)
# Out:
# 0.47830472987298839

# %%
# функция без NumPy
def stupid_sec_av(A):
    S = [A[i] for i in range(len(A))]
    S=sum(S)
    return S/len(A)

#Проверка:
x = np.random.sample((100))
print(stupid_sec_av(x))
print(sec_av(x))

# зададим некоторую последовательность и проверим ее на ваших функциях. 
# Первая функция должна работать ~ в 50 раз быстрее
A = sps.uniform.rvs(size=10 ** 7) 

# %time S1 = sec_av(A)
# %time S2 = stupid_sec_av(A)
#проверим корректность:
np.abs(S1 - S2).sum()<0.00001
# Out:
# 0.541279796328
# 0.541279796328
# Wall time: 17 ms
# Wall time: 2.36 s
# True

# %% [markdown]
# ### Задача 3
#
# Пусть задан некоторый массив $X$. Надо построить новый массив, где все элементы с нечетными индексами требуется заменить на число $a$ (если оно не указано, то на 1). Все элементы с четными индексами исходного массива нужно возвести в куб и записать в обратном порядке относительно позиций этих элементов. Массив $X$ при этом должен остаться без изменений. В конце требуется слить массив X с преобразованным X и вывести в обратном порядке.

# %%
# функция, решающая задачу с помощью NumPy
def transformation(x_src, a=1):
    x=x_src.copy()
    even=[]
    odd=[]
    for i in range(len(x)):
        if i%2!=0:
            odd.append(i)
        else:
            even.append(i)

    ord=list(reversed(even))

    x[odd]=1
    x[ord]=x[even]**3

    x=np.concatenate([x_src,x])

    x=x[::-1]
    
    return x
# Out:
# [  1   1  27   1 125   5   4   3   2   1]

# %%
# функция, решающая задачу  без NumPy
def stupid_transformation(X, a=1):
    # Ваш код здесь
    Y=X.copy()
    rev=[]
    ord=[]
    for i in range(len(Y)):
        if i%2!=0:
            Y[i]=a
        else:
            rev.append(Y[i]**3)
            ord.append(i)
    rev=list(reversed(rev))
   
    for i in range(len(ord)):
        Y[(ord[i])]=rev[i]

    Y=np.concatenate((X,Y))
    Y=list(reversed(Y))
    
    Y=np.array(Y)

    return Y
# Out:
# [  1   1  27   1 125   5   4   3   2   1]

# %%
'''Проверка'''
x=np.random.sample((50))
x=np.array(x)

a=transformation(x)
b=stupid_transformation(x)

print(sum(a-b)<0.00001)
# Out:
# True

# %%
X = sps.uniform.rvs(size=10 ** 7) 
# здесь код эффективнее примерно в 20 раз. 
# если Вы вдруг соберетесь печатать массив без np -- лучше сначала посмотрите на его размер
# %time S1 = transformation(X)
# %time S2 = stupid_transformation(X)
# проверим корректность:
#np.abs(S1 - S2).sum()
print(len(S1))
print(len(S2))
# Out:
# Wall time: 2.82 s
# Wall time: 6.31 s
# 20000000
# 20000000

# %% [markdown]
# Почему методы ***numpy*** оказываются эффективнее?

# %%
'''
Основной причиной является то, что большая часть функция написана на C, который значительно быстрее, чем Python.
Также методы numpy оптимизированы для веторной/матричной формы, за счет того, то происходит преобразование в единый тип.

# %% [markdown]
# ## Дополнительные задачи

# %% [markdown]
# Дополнительные задачи подразумевают, что Вы самостоятельно разберётесь в некоторых функциях ***numpy***, чтобы их сделать.
#
# Эти задачи не являются обязательными, но могут повлиять на Ваш рейтинг в лучшую сторону (точные правила учёта доп. задач будут оглашены позже).

# %% [markdown]
# ### Задача 4*

# %% [markdown]
# Дана функция двух переменных: $f(x, y) = sin(x)cos(y)$ (это просто такой красивый 3D-график), а также дана функция для отрисовки $f(x, y)$ (`draw_f()`), которая принимает на вход двумерную сетку, на которой будет вычисляться функция.
#
# Вам нужно разобраться в том, как строить такие сетки (подсказка - это одна конкретная функция ***numpy***), и подать такую сетку на вход функции отрисовки.

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

def f(x, y):
    '''Функция двух переменных'''
    return np.sin(x) * np.cos(y)

def draw_f(grid_x, grid_y):
    '''Функция отрисовки функции f(x, y)'''
    fig = plt.figure(figsize=(10, 8))
    ax = Axes3D(fig)
    ax.plot_surface(grid_x, grid_y, f(grid_x, grid_y), cmap='inferno', color='b')
    plt.show()

# %%
a = np.linspace(0, np.pi/2, 100)
b = np.linspace(0, np.pi/2, 100)

a,b=np.meshgrid(a,b)

draw_f(a,b)

# %% [markdown]
# ### Задача 5*

# %% [markdown]
# Вам дана картинка. При загрузке её размерность равна 3: **(w, h, num_channels)**, где **w** - ширина картинки в пикселях, **h** - высота картинки в пикселях, **num_channels** - количество каналов *(R, G, B, alpha)*.
#
# Вам нужно "развернуть" картинку в одномерный массив размера w \* h \* num_channels, написав **одну строку кода**.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
path_to_image = './image.png'
image_array = plt.imread(path_to_image)
plt.imshow(image_array);

# %%
flat_image_array = # Ваш код здесь

# %%
# здесь выведите размер нового массива
